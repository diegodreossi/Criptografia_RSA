# %%
import random as rd
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/RSA")

import funcoes_rsa as fr

arq = "/content/drive/MyDrive/Colab Notebooks/RSA/mensagem.txt"
arq2 =  "/content/drive/MyDrive/Colab Notebooks/RSA/chaveprivada.txt"
fr.rsa_descriptografador(arq,arq2)
# Out:
# Mensagem a decodificar: ćė­ ęć
# Mensagem descriptografada: ola mundo
