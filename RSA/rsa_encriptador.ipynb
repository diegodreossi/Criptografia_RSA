# %%
import random as rd
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/RSA")

import funcoes_rsa as fr


acp = "/content/drive/MyDrive/Colab Notebooks/RSA/chaveprivada.txt"
arq = "/content/drive/MyDrive/Colab Notebooks/RSA/mensagem.txt"
fr.rsa_criptografador(acp,arq)
# Out:
# Digite uma mensagem para criptografar: Eternos
# (p) Digite um numero inteiro primo: 19
# (q) Digite um numero inteiro primo: 17
# Chave Publica: (109,323)
# Chave Privada: (37,323)
# Mensagem criptografada: EÀeęćs
# Mensagem descriptografada: Eternos
